# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\saurabh\\Desktop\\pyth\\cars.csv")

# %%
df
# Out:
#                                         name  year  selling_price  km_driven  \
# 0                         Maruti 800 AC BSII  1992          50000     100000
# 1                   Maruti Gypsy E MG410W ST  1995          95000     100000
# 2                   Mahindra Jeep CL 500 MDI  1996         250000      35000
# 3                       Mahindra Jeep MM 540  1996         200000      60000
# 4                   Mahindra Jeep CL 500 MDI  1997         150000     120000
# ...                                      ...   ...            ...        ...
# 4335         Hyundai Venue SX Opt Turbo BSIV  2020        1050000       1100
# 4336  Hyundai Grand i10 1.2 Kappa Magna BSIV  2020         545000       5000
# 4337      Ford Figo Aspire 1.5 TDCi Titanium  2020         530000      45000
# 4338                         Tata Harrier XE  2020         426000       1000
# 4339               Honda Amaze S Petrol BSIV  2020         614000       1000
#
# ...

# %%
df.shape
# Out:
# (4340, 8)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0        Maruti 800 AC BSII  1992          50000     100000  Petrol
# 1  Maruti Gypsy E MG410W ST  1995          95000     100000  Petrol
# 2  Mahindra Jeep CL 500 MDI  1996         250000      35000  Diesel
# 3      Mahindra Jeep MM 540  1996         200000      60000  Diesel
# 4  Mahindra Jeep CL 500 MDI  1997         150000     120000  Diesel
#
#   seller_type transmission                 owner
# 0  Individual       Manual  Fourth & Above Owner
# 1  Individual       Manual          Second Owner
# 2  Individual       Manual          Second Owner
# 3  Individual       Manual           First Owner
# 4  Individual       Manual           Third Owner

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
df['fuel'].value_counts()
# Out:
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# Manual       3892
# Automatic     448
# Name: transmission, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: owner, dtype: int64

# %%
df['seller_type'].value_counts()
# Out:
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: seller_type, dtype: int64

# %%
df.tail()
# Out:
#                                         name  year  selling_price  km_driven  \
# 4335         Hyundai Venue SX Opt Turbo BSIV  2020        1050000       1100
# 4336  Hyundai Grand i10 1.2 Kappa Magna BSIV  2020         545000       5000
# 4337      Ford Figo Aspire 1.5 TDCi Titanium  2020         530000      45000
# 4338                         Tata Harrier XE  2020         426000       1000
# 4339               Honda Amaze S Petrol BSIV  2020         614000       1000
#
#         fuel seller_type transmission        owner
# 4335  Petrol  Individual       Manual  First Owner
# 4336  Petrol  Individual       Manual  First Owner
# 4337  Diesel      Dealer       Manual  First Owner
# 4338  Diesel  Individual       Manual  First Owner
# 4339  Petrol  Individual       Manual  First Owner

# %%
df.sample(4)
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 2966    Hyundai Xcent 1.2 Kappa SX  2016         350000      12000  Petrol
# 2455      Tata Indigo Grand Petrol  2014         250000     100000  Petrol
# 865   Maruti Wagon R VXI Minor ABS  2010         260000      50000  Petrol
# 247       Skoda Laura L n K 1.9 PD  2006         350000     100000  Diesel
#
#      seller_type transmission        owner
# 2966  Individual       Manual  First Owner
# 2455  Individual       Manual  First Owner
# 865   Individual       Manual  First Owner
# 247   Individual       Manual  First Owner

# %%
df.T
# Out:
#                                0                         1     \
# name             Maruti 800 AC BSII  Maruti Gypsy E MG410W ST
# year                           1992                      1995
# selling_price                 50000                     95000
# km_driven                    100000                    100000
# fuel                         Petrol                    Petrol
# seller_type              Individual                Individual
# transmission                 Manual                    Manual
# owner          Fourth & Above Owner              Second Owner
#
#                                    2                     3     \
# name           Mahindra Jeep CL 500 MDI  Mahindra Jeep MM 540
# year                               1996                  1996
# selling_price                    250000                200000
# km_driven                         35000                 60000
# fuel                             Diesel                Diesel
# ...

# %%
df.T.T
# Out:
#                                         name  year selling_price km_driven  \
# 0                         Maruti 800 AC BSII  1992         50000    100000
# 1                   Maruti Gypsy E MG410W ST  1995         95000    100000
# 2                   Mahindra Jeep CL 500 MDI  1996        250000     35000
# 3                       Mahindra Jeep MM 540  1996        200000     60000
# 4                   Mahindra Jeep CL 500 MDI  1997        150000    120000
# ...                                      ...   ...           ...       ...
# 4335         Hyundai Venue SX Opt Turbo BSIV  2020       1050000      1100
# 4336  Hyundai Grand i10 1.2 Kappa Magna BSIV  2020        545000      5000
# 4337      Ford Figo Aspire 1.5 TDCi Titanium  2020        530000     45000
# 4338                         Tata Harrier XE  2020        426000      1000
# 4339               Honda Amaze S Petrol BSIV  2020        614000      1000
#
#         fuel seller_type transmission                 owner
# ...

# %%
df.empty   # True for empty dataframe
# Out:
# False

# %%
df2 = df.copy()

# %%
df2 = df2.sort_values(by = ['selling_price' , 'km_driven'])

# %%
df2
# Out:
#                                                    name  year  selling_price  \
# 198                               Ford Ikon 1.6 ZXI NXt  2005          20000
# 35                                    Ford Ikon 1.4 ZXi  2000          22000
# 127                                       Maruti 800 EX  2004          30000
# 1497                                    Tata Nano LX SE  2012          35000
# 748                                  Tata Nano Std BSII  2009          35000
# ...                                                 ...   ...            ...
# 4193                            BMW X5 xDrive 30d xLine  2019        4950000
# 4220                            BMW X5 xDrive 30d xLine  2019        4950000
# 3238            Mercedes-Benz GLS 2016-2020 350d 4MATIC  2016        5500000
# 3273  Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 3234           Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
# ...

# %%
s = df['selling_price'].mean() 
s
# Out:
# 504127.3117511521

# %%
s2 = df.filter(items = ['name' , 'km_driven' , 'selling_price' , 'owner']) 
s2
# Out:
#                                         name  km_driven  selling_price  \
# 0                         Maruti 800 AC BSII     100000          50000
# 1                   Maruti Gypsy E MG410W ST     100000          95000
# 2                   Mahindra Jeep CL 500 MDI      35000         250000
# 3                       Mahindra Jeep MM 540      60000         200000
# 4                   Mahindra Jeep CL 500 MDI     120000         150000
# ...                                      ...        ...            ...
# 4335         Hyundai Venue SX Opt Turbo BSIV       1100        1050000
# 4336  Hyundai Grand i10 1.2 Kappa Magna BSIV       5000         545000
# 4337      Ford Figo Aspire 1.5 TDCi Titanium      45000         530000
# 4338                         Tata Harrier XE       1000         426000
# 4339               Honda Amaze S Petrol BSIV       1000         614000
#
#                      owner
# 0     Fourth & Above Owner
# 1             Second Owner
# 2             Second Owner
# ...

# %%
p = s2['owner']=='First Owner'

# %%
p
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4335     True
# 4336     True
# 4337     True
# 4338     True
# 4339     True
# Name: owner, Length: 4340, dtype: bool

# %%
df['name'].value_counts()
# Out:
# Maruti Swift Dzire VDI                  69
# Maruti Alto 800 LXI                     59
# Maruti Alto LXi                         47
# Hyundai EON Era Plus                    35
# Maruti Alto LX                          35
#                                         ..
# Honda Jazz 1.5 SV i DTEC                 1
# Fiat Linea 1.3 Multijet Emotion          1
# Hyundai Verna Transform CRDi VGT ABS     1
# Hyundai i20 Active 1.4 SX with AVN       1
# Honda Amaze S Petrol BSIV                1
# Name: name, Length: 1491, dtype: int64

# %%
s2.head()
# Out:
#                        name  km_driven  selling_price                 owner
# 0        Maruti 800 AC BSII     100000          50000  Fourth & Above Owner
# 1  Maruti Gypsy E MG410W ST     100000          95000          Second Owner
# 2  Mahindra Jeep CL 500 MDI      35000         250000          Second Owner
# 3      Mahindra Jeep MM 540      60000         200000           First Owner
# 4  Mahindra Jeep CL 500 MDI     120000         150000           Third Owner

# %%
# t = df['name'].where(df['km_driven']>50000 , other = 0)
t = df['name'].where(df['km_driven']<50000 , other = 0) 

t.head(20)
# Out:
# 0                             0
# 1                             0
# 2      Mahindra Jeep CL 500 MDI
# 3                             0
# 4                             0
# 5                             0
# 6                             0
# 7                Maruti 800 Std
# 8     Maruti Omni 5 Str STD LPG
# 9                             0
# 10    Mercedes-Benz E-Class 230
# 11    Mercedes-Benz E-Class 230
# 12                            0
# 13                            0
# 14               Maruti 800 Std
# 15                            0
# 16                            0
# 17                            0
# 18                            0
# 19                            0
# Name: name, dtype: object

# %%
t.value_counts()
# Out:
# 0                                 2697
# Maruti Alto 800 LXI                 40
# Maruti Swift Dzire VDI              30
# Hyundai EON Era Plus                22
# Maruti Wagon R VXI BS IV            18
#                                   ...
# Volkswagen Vento 1.6 Highline        1
# Hyundai i10 Magna 1.1 iTech SE       1
# Maruti Wagon R VXI Optional          1
# Datsun GO T Option BSIV              1
# Honda Amaze S Petrol BSIV            1
# Name: name, Length: 744, dtype: int64

# %%
s2
# Out:
#                                         name  km_driven  selling_price  \
# 0                         Maruti 800 AC BSII     100000          50000
# 1                   Maruti Gypsy E MG410W ST     100000          95000
# 2                   Mahindra Jeep CL 500 MDI      35000         250000
# 3                       Mahindra Jeep MM 540      60000         200000
# 4                   Mahindra Jeep CL 500 MDI     120000         150000
# ...                                      ...        ...            ...
# 4335         Hyundai Venue SX Opt Turbo BSIV       1100        1050000
# 4336  Hyundai Grand i10 1.2 Kappa Magna BSIV       5000         545000
# 4337      Ford Figo Aspire 1.5 TDCi Titanium      45000         530000
# 4338                         Tata Harrier XE       1000         426000
# 4339               Honda Amaze S Petrol BSIV       1000         614000
#
#                      owner
# 0     Fourth & Above Owner
# 1             Second Owner
# 2             Second Owner
# ...

# %%
s2['first'] = s2['name'].where(s2['owner']=='First Owner' , other = 0)

# %%
s2.sample(25)
# Out:
#                                            name  km_driven  selling_price  \
# 2498  Ford Figo Aspire 1.2 Ti-VCT Titanium Plus      14272         530000
# 300                         Maruti Alto 800 LXI     132000         165000
# 4006          Tata Safari Storme VX Varicor 400      15000        1085000
# 1390                       Hyundai Verna 1.6 SX      86000         390000
# 2572                   Hyundai Grand i10 Sportz      90000         350000
# 3139       Ford EcoSport 1.5 TDCi Titanium BSIV      81595         650000
# 3900                    Maruti Baleno Delta 1.3      15000         650000
# 4244                     Maruti Swift Dzire LDI       5000         650000
# 501                      Maruti Swift Dzire VDi      82000         250000
# 2652                Hyundai Xcent 1.1 CRDi Base      60000         420000
# 4010                  Hyundai Elantra 2.0 SX AT      10000        1575000
# 1564                         Hyundai EON Sportz      80000         150000
# ...

# %%
t3 = s2['km_driven'].min() 
t3
# Out:
# 1

# %%
t4 = s2['km_driven'].max() 
t4
# Out:
# 806599

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df = pd.read_csv("C:\\Users\\saurabh\\Desktop\\pyth\\covid_toy.csv")

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['has_covid'].value_counts()
# Out:
# No     55
# Yes    45
# Name: has_covid, dtype: int64

# %%
df = df.sort_values(by = ['age' , 'fever' ])

# %%
df.head(20)
# Out:
#     age  gender  fever   cough       city has_covid
# 98    5  Female   98.0  Strong     Mumbai        No
# 88    5  Female  100.0    Mild    Kolkata        No
# 75    5    Male  102.0    Mild    Kolkata       Yes
# 59    6  Female  104.0    Mild    Kolkata       Yes
# 77    8  Female  101.0    Mild    Kolkata        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
# 63   10    Male  100.0    Mild  Bangalore        No
# 78   11    Male  100.0    Mild  Bangalore       Yes
# 51   11  Female  100.0  Strong    Kolkata       Yes
# 20   12    Male   98.0  Strong  Bangalore        No
# 95   12  Female  104.0    Mild  Bangalore        No
# 24   13  Female  100.0  Strong    Kolkata        No
# 80   14  Female   99.0    Mild     Mumbai       Yes
# 6    14    Male  101.0  Strong  Bangalore        No
# 30   15    Male  101.0    Mild      Delhi       Yes
# 85   16  Female  103.0    Mild  Bangalore       Yes
# 28   16    Male  104.0    Mild    Kolkata        No
# ...

# %%
df['cough'].value_counts()
# Out:
# Mild      62
# Strong    38
# Name: cough, dtype: int64

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['city'].value_counts()
# Out:
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: city, dtype: int64

# %%
df['Mumbai'] = df['has_covid'].where(df['city']=='Mumbai' , other = 0)

# %%
df.head(25)
# Out:
#     age  gender  fever   cough       city has_covid Mumbai
# 98    5  Female   98.0  Strong     Mumbai        No     No
# 88    5  Female  100.0    Mild    Kolkata        No      0
# 75    5    Male  102.0    Mild    Kolkata       Yes      0
# 59    6  Female  104.0    Mild    Kolkata       Yes      0
# 77    8  Female  101.0    Mild    Kolkata        No      0
# 99   10  Female   98.0  Strong    Kolkata       Yes      0
# 63   10    Male  100.0    Mild  Bangalore        No      0
# 78   11    Male  100.0    Mild  Bangalore       Yes      0
# 51   11  Female  100.0  Strong    Kolkata       Yes      0
# 20   12    Male   98.0  Strong  Bangalore        No      0
# 95   12  Female  104.0    Mild  Bangalore        No      0
# 24   13  Female  100.0  Strong    Kolkata        No      0
# 80   14  Female   99.0    Mild     Mumbai       Yes    Yes
# 6    14    Male  101.0  Strong  Bangalore        No      0
# 30   15    Male  101.0    Mild      Delhi       Yes      0
# ...

# %%
df['Mumbai'].value_counts()
# Out:
# 0      84
# No      8
# Yes     8
# Name: Mumbai, dtype: int64

# %%
df['Delhi'] = df['has_covid'].where(df['city']=='Delhi' , other = 0)

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid Mumbai Delhi
# 98    5  Female   98.0  Strong     Mumbai        No     No     0
# 88    5  Female  100.0    Mild    Kolkata        No      0     0
# 75    5    Male  102.0    Mild    Kolkata       Yes      0     0
# 59    6  Female  104.0    Mild    Kolkata       Yes      0     0
# 77    8  Female  101.0    Mild    Kolkata        No      0     0
# ..  ...     ...    ...     ...        ...       ...    ...   ...
# 41   82    Male    NaN    Mild    Kolkata       Yes      0     0
# 53   83    Male   98.0    Mild      Delhi       Yes      0   Yes
# 72   83  Female  101.0    Mild    Kolkata        No      0     0
# 31   83    Male  103.0    Mild    Kolkata        No      0     0
# 5    84  Female    NaN    Mild  Bangalore       Yes      0     0
#
# [100 rows x 8 columns]

# %%
df['Delhi'].value_counts()
# Out:
# 0      78
# No     13
# Yes     9
# Name: Delhi, dtype: int64
